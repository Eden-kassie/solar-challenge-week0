# %%
# If only Benin file exists for now:
benin = pd.read_csv("data/benin_clean.csv")
benin["Country"] = "Benin"

# Optional placeholders (remove when you add real data)
import pandas as pd
sierra_leone = pd.DataFrame(columns=benin.columns)
togo = pd.DataFrame(columns=benin.columns)

# Combine
df = pd.concat([benin, sierra_leone, togo], ignore_index=True)
df.head()
